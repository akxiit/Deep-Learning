# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()

model.add(Conv2D(96, kernel_size=(7,7), strides=(2,2), input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

model.add(Conv2D(256, kernel_size=(3,3), strides=(2,2)))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

model.add(Conv2D(384, kernel_size=(3,3), strides=(1,1), padding='same'))

model.add(Conv2D(384, kernel_size=(3,3), strides=(3,3), padding='same'))

model.add(Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu'))
model.add(Dense(4096, activation='relu'))
model.add(Dense(1000, activation='relu'))

##here output of lat
model.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4045591046.py in <cell line: 0>()
#      21
#      22 ##here output of lat
# ---> 23 model.add()
#
# TypeError: Sequential.add() missing 1 required positional argument: 'layer'
